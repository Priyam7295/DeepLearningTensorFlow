# %% [markdown]
# ## Hyper paramenters in classification
# 1. **Input Layer shape**
# 2. **Hidden layer(s)**
# 3. **Neurons per hidden layer**
# 4. **Ouput layer shape**
#     1. 1(since one class or the other)
#     2. 1 per class (eg -3 for 3 class)
# 5. **Hidden Activation**
#     1. Usually used RelU
#     2. There are many other (check it out)
# 6. **Output Activation**
#     1. Sigmoid for binary classification
#     2. softmax for multi class classification
# 7. **Loss function**
#     1. Cross Entropy for Binary class Classification
#     ![image.png](data:image/png;base64,...)
#
#     2. Cross Entropy for Multiclass Classification
#     ![image.png](data:image/png;base64,...)
# 8. **Optimizer**
#       SGD ,ADAM ....

# %% [markdown]
# # Classification Types
# 1. Binary classifications
# 2. Multiclass classifications
# 3. Multilabal classifications

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_circles
n_samples=1000
x,y=make_circles(n_samples, noise=0.03 ,random_state=42)

color_list = ["blue", "black"]
colors = [color_list[label] for label in y]
plt.scatter(x[:, 0], x[:, 1], c=colors, alpha=0.6)
# X[:,0] means for all rows of x first val
# X[:,1] means for all rows of x second val
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")

plt.show()

# %%
print("Input shape:->",x.shape)
print("Output shape->",y.shape)

print(x[:5])
print(y[:5])


X_train ,y_train = x[:800],y[:800]
X_test ,y_test = x[800:],y[800:]


print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# Input shape:-> (1000, 2)
# Output shape-> (1000,)
# [[ 0.75424625  0.23148074]
#  [-0.75615888  0.15325888]
#  [-0.81539193  0.17328203]
#  [-0.39373073  0.69288277]
#  [ 0.44220765 -0.89672343]]
# [1 1 1 1 0]
# (800, 2)
# (200, 2)
# (800,)
# (200,)

# %%
import pandas as pd

circles =pd.DataFrame({"X0":x[:,0] ,"X1":x[:,1] ,"label":y})
circles

# print(circles.shape)
# Out:
#            X0        X1  label
# 0    0.754246  0.231481      1
# 1   -0.756159  0.153259      1
# 2   -0.815392  0.173282      1
# 3   -0.393731  0.692883      1
# 4    0.442208 -0.896723      0
# ..        ...       ...    ...
# 995  0.244054  0.944125      0
# 996 -0.978655 -0.272373      0
# 997 -0.136900 -0.810012      1
# 998  0.670362 -0.767502      0
# 999  0.281057  0.963824      0
#
# [1000 rows x 3 columns]

# %%
print(X_train[0].shape)
print(y_train[0].shape)
# Out:
# (2,)
# ()

# %%
## Steps in modelling
import tensorflow as tf
tf.random.set_seed(42)
model= tf.keras.Sequential([
    tf.keras.Input (shape=(2,)),
    tf.keras.layers.Dense(32 ,activation="relu"),

    tf.keras.layers.Dense(1 ,activation="sigmoid")
])

model.compile(
    loss=tf.keras.losses.BinaryCrossentropy(),  # Binary cross-entropy for binary classification
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
    metrics=["accuracy"]   #metrics chnages for classification
)
# step3

history= model.fit(X_train , y_train  ,epochs=5)
# Out:
# Epoch 1/5
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4889 - loss: 0.6907
# Epoch 2/5
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5641 - loss: 0.6741
# Epoch 3/5
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7665 - loss: 0.6530
# Epoch 4/5
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8307 - loss: 0.6264
# Epoch 5/5
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8533 - loss: 0.5930

# %%
import numpy as np

# %%
x_min =x[:,0].min();
x_max=x[:,0].max();
y_min =x[:,1].min();
y_max=x[:,1].max();


xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                        np.arange(y_min, y_max, 0.1))


plt.scatter(xx, yy, color='red', s=1, alpha=0.5, label='Mesh Grid Points')

# %%
import numpy as np
import matplotlib.pyplot as plt

def creating_decision_line(X, y, model):
    plt.scatter(X[:, 0], X[:, 1], c=y, alpha=0.6)

    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1


    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                         np.arange(y_min, y_max, 0.1))

    grid_points = np.c_[xx.ravel(), yy.ravel()] #make xx and yy comnbine into 2d
    y_pred = model.predict(grid_points)

    if len(y_pred[0]) > 1:
        print("Multiclass Classification")
        y_pred = np.argmax(y_pred, axis=1)
        y_pred=y_pred.reshape(xx.shape)
    else:
        print("Binary Classification")
        y_pred = np.round(y_pred).reshape(xx.shape)

    plt.contourf(xx, yy, y_pred, cmap='inferno', alpha=0.2)
    plt.colorbar(label="Prediction Probability")

    plt.xlabel("Feature 1")
    plt.ylabel("Feature 2")
    plt.title("Decision Boundary")
    plt.show()

# Example usage
y_preds = model.predict(X_test)
print(y_preds[:5])

print("Testing the data on X_test and y_test")
creating_decision_line(X_test, y_test, model)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# [[0.5442092 ]
#  [0.63645476]
#  [0.5580342 ]
#  [0.50384605]
#  [0.4321198 ]]
# Testing the data on X_test and y_test
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Binary Classification

# %%
import pandas as pd
pd.DataFrame(history.history)
# Out:
#    accuracy      loss
# 0   0.52000  0.687852
# 1   0.62000  0.668130
# 2   0.82875  0.645267
# 3   0.88250  0.616201
# 4   0.90125  0.580516

# %%
plt.show("Model training curves")
plt.plot(history.history["accuracy"] ,label="accuracy")
plt.plot(history.history["loss"] ,label="loss")
plt.legend()
plt.show()

# %% [markdown]
# ## How to find the best Learning Rate

# %% [markdown]
# #### Aside from the architecture itself ,the layes ,the number of neurons , activations etc ,the most important hyperparameter is **learning rate**.

# %% [markdown]
# #### Deep Leanring means experiment ,You build a model and evaluate it and build and evaluate and so on .....

# %% [markdown]
# There is a trick which will help you find the optimal Learning rate(at least to begin training with)

# %% [markdown]
# ## What will we do for learning rate

# %% [markdown]
# Early in training, the model is far from optimal, and a relatively high learning rate helps make large updates to the weights to quickly move toward a good region in the loss landscape.
# As training progresses, reducing the learning rate allows the model to make smaller, more precise adjustments to the weights, helping it converge to a minimum (ideally, a global minimum).

# %% [markdown]
# # Finding the best learning rate
#
# **Callbacks**: Extra piece of functionality , you can add to your model while training
#
# we are suing learning rate callback

# %%
# def scheduler(epoch ,lr):
#   if(epoch<10):
#     return float(lr)
#   else :
#     return float(lr*tf.math.exp(-0.1))

def scheduler(epoch):
    return 1e-4 * 10**(epoch / 20)

# %%
tf.random.set_seed(42)

model_2 = tf.keras.Sequential([
    tf.keras.Input(shape=(2,)),
    tf.keras.layers.Dense(4 ,activation="relu"),
    tf.keras.layers.Dense(4 ,activation="relu"),
    tf.keras.layers.Dense(1 ,activation="sigmoid")
])



model_2.compile(loss=tf.keras.losses.BinaryCrossentropy() ,
                optimizer=tf.keras.optimizers.Adam(),
                metrics=["accuracy"]
)


lr_scheduler = tf.keras.callbacks.LearningRateScheduler(scheduler)



history_2= model_2.fit(X_train , y_train  ,epochs=100 ,callbacks=[lr_scheduler])
# Out:
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5011 - loss: 0.7215 - learning_rate: 1.0000e-04
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5034 - loss: 0.7194 - learning_rate: 1.1220e-04
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5009 - loss: 0.7171 - learning_rate: 1.2589e-04
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5066 - loss: 0.7148 - learning_rate: 1.4125e-04
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5187 - loss: 0.7123 - learning_rate: 1.5849e-04
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5135 - loss: 0.7097 - learning_rate: 1.7783e-04
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5210 - loss: 0.7070 - learning_rate: 1.9953e-04
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5217 - loss: 0.7043 - learning_rate: 2.2387e-04
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5379 - loss: 0.7016 - learning_rate: 2.5119e-04
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5586 - loss: 0.6989 - learning_rate: 2.8184e-04
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5663 - loss: 0.6962 - learning_rate: 3.1623e-04
# Epoch 12/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5267 - loss: 0.6938 - learning_rate: 3.5481e-04
# Epoch 13/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5244 - loss: 0.6915 - learning_rate: 3.9811e-04
# Epoch 14/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5278 - loss: 0.6895 - learning_rate: 4.4668e-04
# Epoch 15/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5687 - loss: 0.6875 - learning_rate: 5.0119e-04
# Epoch 16/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.
# Epoch 78/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8302 - loss: 0.5163 - learning_rate: 0.7079
# Epoch 79/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9059 - loss: 0.2389 - learning_rate: 0.7943
# Epoch 80/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8935 - loss: 0.3012 - learning_rate: 0.8913
# Epoch 81/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5100 - loss: 0.7089 - learning_rate: 1.0000
# Epoch 82/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5281 - loss: 0.7224 - learning_rate: 1.1220
# Epoch 83/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5186 - loss: 0.7067 - learning_rate: 1.2589
# Epoch 84/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5056 - loss: 0.7051 - learning_rate: 1.4125
# Epoch 85/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5022 - loss: 0.7104 - learning_rate: 1.5849
# Epoch 86/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4885 - loss: 0.7194 - learning_rate: 1.7783
# Epoch 87/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5006 - loss: 0.7329 - learning_rate: 1.9953
# Epoch 88/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4871 - loss: 0.7485 - learning_rate: 2.2387
# Epoch 89/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4899 - loss: 0.7584 - learning_rate: 2.5119
# Epoch 90/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5045 - loss: 0.7449 - learning_rate: 2.8184
# Epoch 91/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4949 - loss: 0.7122 - learning_rate: 3.1623
# Epoch 92/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4824 - loss: 0.7111 - learning_rate: 3.5481
# Epoch 93/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4798 - loss: 0.7157 - learning_rate: 3.9811
# Epoch 94/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4732 - loss: 0.7231 - learning_rate: 4.4668
# Epoch 95/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4732 - loss: 0.7407 - learning_rate: 5.0119
# Epoch 96/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4849 - loss: 0.7786 - learning_rate: 5.6234
# Epoch 97/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4844 - loss: 0.8201 - learning_rate: 6.3096
# Epoch 98/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4892 - loss: 0.8645 - learning_rate: 7.0795
# Epoch 99/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4892 - loss: 0.9079 - learning_rate: 7.9433
# Epoch 100/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4892 - loss: 0.9525 - learning_rate: 8.9125

# %%
plt.plot(history_2.history["learning_rate"])

# %%
pd.DataFrame(history_2.history).plot(figsize=(10,7))
# Out:
# <Axes: >

# %%
lrs=history_2.history["learning_rate"]
plt.figure(figsize=(10,7))
plt.semilogx(lrs ,history_2.history["loss"])
plt.xlabel("Learning rate")
plt.ylabel("Loss")
plt.title("Lr vs loss")
# Out:
# Text(0.5, 1.0, 'Lr vs loss')

# %% [markdown]
# # Ideal learning rate is along the downward slope that is sliglty greater than 0.01

# %% [markdown]
# # Othere examples of learnign rate
# 0.1 0.01 0.001 0.0001
#
# So either try all these or find ideal learning rate using scheduler

# %% [markdown]
# ## Other evaluations
#
# **1**. Accuracy
#
# **2**. Recall
#
# **3**. Precision
#
# **4**. F1-score
#
# **5**. Confusion matrix

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
loss ,accuracy = model.evaluate(X_test ,y_test)
print(f"Model loss on the test set:{loss}")
print(f"Model accuracy on the test set :{(accuracy*100):.2f}")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7842 - loss: 0.5841
# Model loss on the test set:0.5754573941230774
# Model accuracy on the test set :79.50

# %%
## Creating Confusion Matrix

from sklearn.metrics import confusion_matrix

y_preds=model.predict(X_test)

y_preds=tf.round(y_preds)


confusion_matrix=confusion_matrix(y_test ,y_preds)
print(confusion_matrix)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# [[99  2]
#  [39 60]]

# %% [markdown]
# #### make pretty

# %%
import matplotlib.pyplot as plt
import numpy
from sklearn import metrics

def conf_perc(conf_matrix):
    # Normalize by row (each row is divided by the row sum)
    row_sums = tf.reduce_sum(conf_matrix, axis=1, keepdims=True)
    return conf_matrix / row_sums

confusion_metrics_percentage= conf_perc(confusion_matrix).numpy()

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix=confusion_metrics_percentage, display_labels=[0, 1])

# Plot with a blue color map (light to dark blue)
fig, ax = plt.subplots(figsize=(6, 6))
cm_display.plot(cmap=plt.cm.Blues, ax=ax)

plt.title("Confusion Matrix", fontsize=14)
plt.xlabel("Predicted Label", fontsize=12)
plt.ylabel("True Label", fontsize=12)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2a450c479f6b> in <cell line: 10>()
#       8     return conf_matrix / row_sums
#       9
# ---> 10 confusion_metrics_percentage= conf_perc(confusion_matrix).numpy()
#      11
#      12 cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix=confusion_metrics_percentage, display_labels=[0, 1])
#
# NameError: name 'confusion_matrix' is not defined
